# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# modelado (install scikit-learn)
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge


# metricas
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score

# optimizar
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# Guardado de modelo
from joblib import dump

# %%
archivo="https://raw.githubusercontent.com/4GeeksAcademy/regularized-linear-regression-project-tutorial/main/demographic_health_data.csv"

df_original = pd.read_csv(archivo, sep=",")
df = pd.read_csv(archivo, sep=",")

datos,atributos=df.shape
print(f"Contamos con {datos} cantidad de datos y {atributos} atributos.")
print()

# Valores duplicados

duplicados = df.duplicated()
num_duplicados = duplicados.sum()

print(f"Contamos con {num_duplicados} datos duplicados.")
print()


# Obtener información sobre tipos de datos y valores no nulos
pd.set_option('display.max_info_columns',500)
df.info()


df.isnull().sum().sort_values(ascending=False)
# Out:
# Contamos con 3140 cantidad de datos y 108 atributos.
#
# Contamos con 0 datos duplicados.
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3140 entries, 0 to 3139
# Data columns (total 108 columns):
#  #    Column                                                                         Non-Null Count  Dtype
# ---   ------                                                                         --------------  -----
#  0    fips                                                                           3140 non-null   int64
#  1    TOT_POP                                                                        3140 non-null   int64
#  2    0-9                                                                            3140 non-null   int64
#  3    0-9 y/o % of total pop                                                         3140 non-null   float64
#  4    19-Oct                                                                         3140 non-null   int64
#  5    10-19 y/o % of total pop                                                       3140 non-null   float64
#  6    20-29                                                                          3140 non-null   int64
#  7    20-29 y/o % of total pop                                                       3140 non-null   float64
#  8    30-39                                                                          3140 non-null   int64
#  9    30-39 y/o % of total pop                                                       3140 non-null   float64
#  10   40-49                                                                          3140 non-null   int64
#  11   40-49 y/o % of total pop                                                       3140 non-null   float64
#  12   50-59                                                                          3140 non-null   int64
#  13   50-59 y/o % of total pop                                                       3140 non-null   float64
#  14   60-69                                                                          3140 non-null   int64
#  15   60-69 y/o % of total pop                                                       3140 non-null   float64
#  16   70-79                                                                          3140 non-null   int64
#  17   70-79 y/o % of total pop                                                       3140 non-null   float64
#  18   80+                                                                            3140 non-null   int64
#  19   80+ y/o % of total pop                                                         3140 non-null   float64
#  20   White-alone pop                                                                3140 non-null   int64
#  21   % White-alone                                                                  3140 non-null   float64
#  22   Black-alone pop                                                                3140 non-null   int64
#  23   % Black-alone                                                                  3140 non-null   float64
#  24   Native American/American Indian-alone pop                                      3140 non-null   int64
#  25   % NA/AI-alone                                                                  3140 non-null   float64
#  26   Asian-alone pop                                                                3140 non-null   int64
#  27   % Asian-alone                                                                  3140 non-null   float64
#  28   Hawaiian/Pacific Islander-alone pop                                            3140 non-null   int64
#  29   % Hawaiian/PI-alone                                                            3140 non-null   float64
#  30   Two or more races pop                                                          3140 non-null   int64
#  31   % Two or more races                                                            3140 non-null   float64
#  32   POP_ESTIMATE_2018                                                              3140 non-null   int64
#  33   N_POP_CHG_2018                                                                 3140 non-null   int64
#  34   GQ_ESTIMATES_2018                                                              3140 non-null   int64
#  35   R_birth_2018                                                                   3140 non-null   float64
#  36   R_death_2018                                                                   3140 non-null   float64
#  37   R_NATURAL_INC_2018                                                             3140 non-null   float64
#  38   R_INTERNATIONAL_MIG_2018                                                       3140 non-null   float64
#  39   R_DOMESTIC_MIG_2018                                                            3140 non-null   float64
#  40   R_NET_MIG_2018                                                                 3140 non-null   float64
#  41   Less than a high school diploma 2014-18                                        3140 non-null   int64
#  42   High school diploma only 2014-18                                               3140 non-null   int64
#  43   Some college or associate's degree 2014-18                                     3140 non-null   int64
#  44   Bachelor's degree or higher 2014-18                                            3140 non-null   int64
#  45   Percent of adults with less than a high school diploma 2014-18                 3140 non-null   float64
#  46   Percent of adults with a high school diploma only 2014-18                      3140 non-null   float64
#  47   Percent of adults completing some college or associate's degree 2014-18        3140 non-null   float64
#  48   Percent of adults with a bachelor's degree or higher 2014-18                   3140 non-null   float64
#  49   POVALL_2018                                                                    3140 non-null   int64
#  50   PCTPOVALL_2018                                                                 3140 non-null   float64
#  51   PCTPOV017_2018                                                                 3140 non-null   float64
#  52   PCTPOV517_2018                                                                 3140 non-null   float64
#  53   MEDHHINC_2018                                                                  3140 non-null   int64
#  54   CI90LBINC_2018                                                                 3140 non-null   int64
#  55   CI90UBINC_2018                                                                 3140 non-null   int64
#  56   Civilian_labor_force_2018                                                      3140 non-null   int64
#  57   Employed_2018                                                                  3140 non-null   int64
#  58   Unemployed_2018                                                                3140 non-null   int64
#  59   Unemployment_rate_2018                                                         3140 non-null   float64
#  60   Median_Household_Income_2018                                                   3140 non-null   int64
#  61   Med_HH_Income_Percent_of_State_Total_2018                                      3140 non-null   float64
#  62   Active Physicians per 100000 Population 2018 (AAMC)                            3140 non-null   float64
#  63   Total Active Patient Care Physicians per 100000 Population 2018 (AAMC)         3140 non-null   float64
#  64   Active Primary Care Physicians per 100000 Population 2018 (AAMC)               3140 non-null   float64
#  65   Active Patient Care Primary Care Physicians per 100000 Population 2018 (AAMC)  3140 non-null   float64
#  66   Active General Surgeons per 100000 Population 2018 (AAMC)                      3140 non-null   float64
#  67   Active Patient Care General Surgeons per 100000 Population 2018 (AAMC)         3140 non-null   float64
#  68   Total nurse practitioners (2019)                                               3140 non-null   float64
#  69   Total physician assistants (2019)                                              3140 non-null   float64
#  70   Total Hospitals (2019)                                                         3140 non-null   float64
#  71   Internal Medicine Primary Care (2019)                                          3140 non-null   float64
#  72   Family Medicine/General Practice Primary Care (2019)                           3140 non-null   float64
#  73   Total Specialist Physicians (2019)                                             3140 non-null   float64
#  74   ICU Beds_x                                                                     3140 non-null   int64
#  75   Total Population                                                               3140 non-null   int64
#  76   Population Aged 60+                                                            3140 non-null   int64
#  77   Percent of Population Aged 60+                                                 3140 non-null   float64
#  78   COUNTY_NAME                                                                    3140 non-null   object
#  79   STATE_NAME                                                                     3140 non-null   object
#  80   STATE_FIPS                                                                     3140 non-null   int64
#  81   CNTY_FIPS                                                                      3140 non-null   int64
#  82   county_pop2018_18 and older                                                    3140 non-null   int64
#  83   anycondition_prevalence                                                        3140 non-null   float64
#  84   anycondition_Lower 95% CI                                                      3140 non-null   float64
#  85   anycondition_Upper 95% CI                                                      3140 non-null   float64
#  86   anycondition_number                                                            3140 non-null   int64
#  87   Obesity_prevalence                                                             3140 non-null   float64
#  88   Obesity_Lower 95% CI                                                           3140 non-null   float64
#  89   Obesity_Upper 95% CI                                                           3140 non-null   float64
#  90   Obesity_number                                                                 3140 non-null   int64
#  91   Heart disease_prevalence                                                       3140 non-null   float64
#  92   Heart disease_Lower 95% CI                                                     3140 non-null   float64
#  93   Heart disease_Upper 95% CI                                                     3140 non-null   float64
#  94   Heart disease_number                                                           3140 non-null   int64
#  95   COPD_prevalence                                                                3140 non-null   float64
#  96   COPD_Lower 95% CI                                                              3140 non-null   float64
#  97   COPD_Upper 95% CI                                                              3140 non-null   float64
#  98   COPD_number                                                                    3140 non-null   int64
#  99   diabetes_prevalence                                                            3140 non-null   float64
#  100  diabetes_Lower 95% CI                                                          3140 non-null   float64
#  101  diabetes_Upper 95% CI                                                          3140 non-null   float64
#  102  diabetes_number                                                                3140 non-null   int64
#  103  CKD_prevalence                                                                 3140 non-null   float64
#  104  CKD_Lower 95% CI                                                               3140 non-null   float64
#  105  CKD_Upper 95% CI                                                               3140 non-null   float64
#  106  CKD_number                                                                     3140 non-null   int64
#  107  Urban_rural_code                                                               3140 non-null   int64
# dtypes: float64(61), int64(45), object(2)
# memory usage: 2.6+ MB
# fips                      0
# TOT_POP                   0
# 0-9                       0
# 0-9 y/o % of total pop    0
# 19-Oct                    0
#                          ..
# CKD_prevalence            0
# CKD_Lower 95% CI          0
# CKD_Upper 95% CI          0
# CKD_number                0
# Urban_rural_code          0
# Length: 108, dtype: int64

# %%
df.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# 2                 12.865239  ...         2373                 19.7
# 3                 13.897321  ...         1789                 14.1
# 4                 11.901798  ...         4661                 13.5
#
#    diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 0                   11.9                   13.8             5462
# 1                   11.0                   13.1            20520
# 2                   18.6                   20.6             3870
# 3                   13.2                   14.9             2511
# 4                   12.6                   14.5             6017
#
#    CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 0             3.1               2.9               3.3        1326
# 1             3.2               3.0               3.5        5479
# 2             4.5               4.2               4.8         887
# 3             3.3               3.1               3.6         595
# 4             3.4               3.2               3.7        1507
#
#    Urban_rural_code
# 0                 3
# 1                 4
# 2                 6
# 3                 2
# 4                 2
#
# [5 rows x 108 columns]

# %% [markdown]
# Vamos a analizar la población con obesidad. Nuestra variable objetivo será la numero 90 "Obesity_number"

# %%
# Seleccionar sólo columnas categóricas
object_columns = df.select_dtypes(include=['object'])

object_columns.head()

state_counts = df["STATE_NAME"].value_counts()

#Eliminar las filas (si el porcentaje es bajo) de los que tengan pocos estados. 

# Filtrar el DataFrame, conservando solo las filas donde "STATE_NAME" aparece 5 o más veces
df_filtered = df[df["STATE_NAME"].isin(state_counts[state_counts > 5].index)]

# Mostrar las primeras filas del DataFrame filtrado
df_filtered
# Out:
#        fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0      1001    55601   6787               12.206615    7637
# 1      1003   218022  24757               11.355276   26913
# 2      1005    24881   2732               10.980266    2960
# 3      1007    22400   2456               10.964286    2596
# 4      1009    57840   7095               12.266598    7570
# ...     ...      ...    ...                     ...     ...
# 3135  56037    43051   6104               14.178532    6326
# 3136  56039    23081   2384               10.328842    2185
# 3137  56041    20299   3121               15.375142    3205
# 3138  56043     7885    858               10.881420    1113
# 3139  56045     6967    780               11.195637     779
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                    13.735364   6878                 12.370281   7089
# 1                    12.344167  23579                 10.814964  25213
# 2                    11.896628   3268                 13.134520   3201
# 3                    11.589286   3029                 13.522321   3113
# 4                    13.087828   6742                 11.656293   6884
# ...                        ...    ...                       ...    ...
# 3135                 14.694200   5359                 12.448027   6577
# 3136                  9.466661   2967                 12.854729   4093
# 3137                 15.788955   2153                 10.606434   2702
# 3138                 14.115409    715                  9.067850    903
# 3139                 11.181283    681                  9.774652    906
#
#       30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                    12.749771  ...         3644                 12.9
# 1                    11.564429  ...        14692                 12.0
# 2                    12.865239  ...         2373                 19.7
# 3                    13.897321  ...         1789                 14.1
# 4                    11.901798  ...         4661                 13.5
# ...                        ...  ...          ...                  ...
# 3135                 15.277229  ...         2098                  8.9
# 3136                 17.733200  ...          928                  7.2
# 3137                 13.311001  ...         1163                 10.4
# 3138                 11.452124  ...          506                 11.3
# 3139                 13.004162  ...          480                 11.7
#
#       diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 0                      11.9                   13.8             5462
# 1                      11.0                   13.1            20520
# 2                      18.6                   20.6             3870
# 3                      13.2                   14.9             2511
# 4                      12.6                   14.5             6017
# ...                     ...                    ...              ...
# 3135                    8.3                    9.6             2834
# 3136                    6.5                    8.0             1360
# 3137                    9.5                   11.2             1500
# 3138                   10.3                   12.1              686
# 3139                   10.7                   12.7              644
#
#       CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 0                3.1               2.9               3.3        1326
# 1                3.2               3.0               3.5        5479
# 2                4.5               4.2               4.8         887
# 3                3.3               3.1               3.6         595
# 4                3.4               3.2               3.7        1507
# ...              ...               ...               ...         ...
# 3135             2.6               2.4               2.8         821
# 3136             2.4               2.2               2.6         447
# 3137             3.0               2.8               3.2         430
# 3138             3.4               3.2               3.7         207
# 3139             3.4               3.1               3.6         185
#
#       Urban_rural_code
# 0                    3
# 1                    4
# 2                    6
# 3                    2
# 4                    2
# ...                ...
# 3135                 5
# 3136                 5
# 3137                 5
# 3138                 6
# 3139                 6
#
# [3126 rows x 108 columns]

# %%
#state_counts[state_counts > 5] filtra las categorías con más de 5 ocurrencias.
#.index extrae los nombres de estas categorías.
#df["STATE_NAME"].isin(...) crea un filtro booleano para conservar solo las filas donde STATE_NAME está en las categorías seleccionadas.
#df[df["STATE_NAME"].isin(...)] aplica este filtro al DataFrame original, generando uno filtrado.

# %%
df_filtered["STATE_NAME"].value_counts()
# Out:
# STATE_NAME
# Texas             254
# Georgia           159
# Virginia          133
# Kentucky          120
# Missouri          115
# Kansas            105
# Illinois          102
# North Carolina    100
# Iowa               99
# Tennessee          95
# Nebraska           93
# Indiana            92
# Ohio               88
# Minnesota          87
# Michigan           83
# Mississippi        82
# Oklahoma           77
# Arkansas           75
# Wisconsin          72
# Pennsylvania       67
# Florida            67
# Alabama            67
# South Dakota       66
# Louisiana          64
# Colorado           64
# New York           62
# California         58
# Montana            56
# West Virginia      55
# North Dakota       53
# South Carolina     46
# Idaho              44
# Washington         39
# Oregon             36
# New Mexico         33
# Utah               29
# Alaska             27
# Maryland           24
# Wyoming            23
# New Jersey         21
# Nevada             17
# Maine              16
# Arizona            15
# Vermont            14
# Massachusetts      14
# New Hampshire      10
# Connecticut         8
# Name: count, dtype: int64

# %%
#elimino "county_name"
df=df_filtered.drop(columns=["COUNTY_NAME"])

# %%
#columna numerica
numerica_columna = df.select_dtypes(include=['number'])
numerica_columna.head()
# Out:
#    fips  TOT_POP    0-9  0-9 y/o % of total pop  19-Oct  \
# 0  1001    55601   6787               12.206615    7637
# 1  1003   218022  24757               11.355276   26913
# 2  1005    24881   2732               10.980266    2960
# 3  1007    22400   2456               10.964286    2596
# 4  1009    57840   7095               12.266598    7570
#
#    10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 0                 13.735364   6878                 12.370281   7089
# 1                 12.344167  23579                 10.814964  25213
# 2                 11.896628   3268                 13.134520   3201
# 3                 11.589286   3029                 13.522321   3113
# 4                 13.087828   6742                 11.656293   6884
#
#    30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 0                 12.749771  ...         3644                 12.9
# 1                 11.564429  ...        14692                 12.0
# 2                 12.865239  ...         2373                 19.7
# 3                 13.897321  ...         1789                 14.1
# 4                 11.901798  ...         4661                 13.5
#
#    diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 0                   11.9                   13.8             5462
# 1                   11.0                   13.1            20520
# 2                   18.6                   20.6             3870
# 3                   13.2                   14.9             2511
# 4                   12.6                   14.5             6017
#
#    CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 0             3.1               2.9               3.3        1326
# 1             3.2               3.0               3.5        5479
# 2             4.5               4.2               4.8         887
# 3             3.3               3.1               3.6         595
# 4             3.4               3.2               3.7        1507
#
#    Urban_rural_code
# 0                 3
# 1                 4
# 2                 6
# 3                 2
# 4                 2
#
# [5 rows x 106 columns]

# %%
# Dividimos el conjunto de datos en muestras de train y test

X = df.drop("Obesity_number", axis = 1)
y = df["Obesity_number"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 35)

print(X_train.shape, X_test.shape)
# Out:
# (2500, 106) (626, 106)

# %%
#escalado variables numericas
num_variables=X_train.select_dtypes(include=['number']).columns

# instancio el escalador
scaler = StandardScaler()

# entreno el escalador con los datos de entrenamiento
scaler.fit(X_train[num_variables])

# aplico el escalador en ambos
X_train_num_scal = scaler.transform(X_train[num_variables])
X_train_num_scal = pd.DataFrame(X_train_num_scal, index = X_train.index, columns = num_variables)

X_test_num_scal = scaler.transform(X_test[num_variables])
X_test_num_scal = pd.DataFrame(X_test_num_scal, index = X_test.index, columns = num_variables)

X_train_num_scal.head()
# Out:
#           fips   TOT_POP       0-9  0-9 y/o % of total pop    19-Oct  \
# 1314 -0.214815 -0.201426 -0.192796                0.503681 -0.200593
# 1546 -0.073574 -0.228568 -0.224247                0.291851 -0.232958
# 930  -0.674279 -0.296146 -0.294352               -0.564016 -0.305380
# 1814  0.318924 -0.187502 -0.179611                0.429574 -0.190470
# 2688  1.202244 -0.280212 -0.277552                0.127174 -0.289054
#
#       10-19 y/o % of total pop     20-29  20-29 y/o % of total pop     30-39  \
# 1314                  0.448347 -0.212185                 -0.633212 -0.197932
# 1546                  0.173760 -0.226739                 -0.367752 -0.214420
# 930                  -1.436997 -0.278597                 -1.070893 -0.271421
# 1814                  0.154440 -0.193473                 -0.265528 -0.185377
# 2688                 -0.469183 -0.254576                  1.735674 -0.252496
#
#       30-39 y/o % of total pop  ...  COPD_number  diabetes_prevalence  \
# 1314                 -0.356831  ...    -0.251835            -0.941786
# 1546                  0.118610  ...    -0.228578            -0.140353
# 930                  -1.839054  ...    -0.345050             1.061797
# 1814                 -0.210702  ...    -0.224241             1.498943
# 2688                  1.549457  ...    -0.331473            -0.140353
#
#       diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 1314              -0.945892              -0.936223        -0.214651
# 1546              -0.189626              -0.127850        -0.223758
# 930                1.020399               1.172577        -0.294722
# 1814               1.511972               1.488897        -0.133394
# 2688              -0.038373              -0.233289        -0.279724
#
#       CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 1314       -0.259431         -0.207095         -0.182082   -0.199190
# 1546       -0.084848         -0.019168         -0.020030   -0.223663
# 930         1.486405          1.484240          1.438438   -0.296311
# 1814        1.660988          1.672167          1.600490   -0.141917
# 2688       -0.608598         -0.582947         -0.668237   -0.283626
#
#       Urban_rural_code
# 1314          0.898353
# 1546          0.898353
# 930           0.898353
# 1814          0.236437
# 2688          0.898353
#
# [5 rows x 105 columns]

# %%
cat_variables = ["STATE_NAME"]

X_train_cat_le = X_train.copy()
X_test_cat_le = X_test.copy()

# instancio el encoder

label_encoder_sn = LabelEncoder()

# entreno el encoder con los datos de entrenamiento

label_encoder_sn.fit(X_train['STATE_NAME'])

# aplico el encoder en ambos

X_train_cat_le['STATE_NAME_le'] = label_encoder_sn.transform(X_train['STATE_NAME'])
X_test_cat_le['STATE_NAME_le'] = label_encoder_sn.transform(X_test['STATE_NAME'])

X_train_cat_le.head()
# Out:
#        fips  TOT_POP   0-9  0-9 y/o % of total pop  19-Oct  \
# 1314  27005    34371  4463               12.984784    4646
# 1546  29131    25336  3175               12.531576    3300
# 930   20089     2841   304               10.700458     288
# 1814  35039    39006  5003               12.826232    5067
# 2688  48335     8145   992               12.179251     967
#
#       10-19 y/o % of total pop  20-29  20-29 y/o % of total pop  30-39  \
# 1314                 13.517209   3544                 10.311018   3834
# 1546                 13.024945   2823                 11.142248   3029
# 930                  10.137276    254                  8.940514    246
# 1814                 12.990309   4471                 11.462339   4447
# 2688                 11.872314   1444                 17.728668   1170
#
#       30-39 y/o % of total pop  ...  diabetes_prevalence  \
# 1314                 11.154753  ...                 10.5
# 1546                 11.955320  ...                 12.7
# 930                   8.658923  ...                 16.0
# 1814                 11.400810  ...                 17.2
# 2688                 14.364641  ...                 12.7
#
#       diabetes_Lower 95% CI  diabetes_Upper 95% CI  diabetes_number  \
# 1314                    9.6                   11.4             2734
# 1546                   11.6                   13.7             2465
# 930                    14.8                   17.4              369
# 1814                   16.1                   18.3             5134
# 2688                   12.0                   13.4              812
#
#       CKD_prevalence  CKD_Lower 95% CI  CKD_Upper 95% CI  CKD_number  \
# 1314             3.3               3.1               3.6         857
# 1546             3.4               3.2               3.7         666
# 930              4.3               4.0               4.6          99
# 1814             4.4               4.1               4.7        1304
# 2688             3.1               2.9               3.3         198
#
#       Urban_rural_code  STATE_NAME_le
# 1314                 6             20
# 1546                 6             22
# 930                  6             13
# 1814                 5             28
# 2688                 6             39
#
# [5 rows x 107 columns]

# %%
X_train_final = pd.concat([X_train_num_scal, X_train_cat_le['STATE_NAME_le']], axis=1)
X_test_final = pd.concat([X_test_num_scal, X_test_cat_le['STATE_NAME_le']], axis=1)

# %%
# como guardar los datos procesados como archivo CSV
X_train_final.to_csv('../data/processed/X_train.csv', index=False)
X_test_final.to_csv('../data/processed/X_test.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

# %%
# modelo
reg_lin = LinearRegression()

# entrenamiento
reg_lin.fit(X_train_final, y_train)

# predicción
y_pred = reg_lin.predict(X_test_final)
y_pred

# metricas
mse_rl = mean_squared_error(y_test, y_pred)
rmse_rl = np.sqrt(mse_rl)
r2_rl = r2_score(y_test, y_pred)

print("MSE: ", mse_rl)
print("RMSE: ", rmse_rl)
print("Coeficiente de determinación: ", r2_rl)
# Out:
# MSE:  9284917.372798674
# RMSE:  3047.116238806566
# Coeficiente de determinación:  0.9984972012355045

# %%
# modelo regularizacion lasso
reg_lasso = Lasso(alpha = 0.001, max_iter = 8000)

# entrenamiento
reg_lasso.fit(X_train_final, y_train)

# prediccion
y_pred = reg_lasso.predict(X_test_final)
y_pred

# metricas
mse_l1 = mean_squared_error(y_test, y_pred)
rmse_l1 = np.sqrt(mse_l1)
r2_l1 = r2_score(y_test, y_pred)

print("MSE: ", mse_l1)
print("RMSE: ", rmse_l1)
print("Coeficiente de determinación: ", r2_l1)
# Out:
# MSE:  7934344.769970222
# RMSE:  2816.79689895637
# Coeficiente de determinación:  0.9987157964859951
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.958e+09, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# el mododelo lasso es un po mejor ya que el error es de 2816 cuando el el de regresion lineal es de 3047

# %%
# modelo regularizacion ridge
reg_ridge = Ridge(alpha = 0.0000000001, max_iter = 400)

# entrenamiento
reg_ridge.fit(X_train_final, y_train)

# prediccion
y_pred = reg_ridge.predict(X_test_final)
y_pred

# metricas
mse_l2 = mean_squared_error(y_test, y_pred)
rmse_l2 = np.sqrt(mse_l2)
r2_l2 = r2_score(y_test, y_pred)

print("MSE: ", mse_l2)
print("RMSE: ", rmse_l2)
print("Coeficiente de determinación: ", r2_l2)
# Out:
# MSE:  9292429.909192516
# RMSE:  3048.348718436346
# Coeficiente de determinación:  0.998495985303261
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:215: LinAlgWarning: Ill-conditioned matrix (rcond=6.35767e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
# Datos a nivel informativo y comparativo
data = {
    'Modelo': ['Regresión lineal', "Regularización Lasso", "Regularización Ridge"],
    'MSE': [mse_rl, mse_l1, mse_l2],
    'RMSE': [rmse_rl, rmse_l1, rmse_l2],
    'R²': [r2_rl, r2_l1, r2_l2]
}

# Crear el DataFrame
resultados = pd.DataFrame(data)

# Mostrar el DataFrame
print(resultados)
# Out:
#                  Modelo           MSE         RMSE        R²
# 0      Regresión lineal  9.284917e+06  3047.116239  0.998497
# 1  Regularización Lasso  7.934345e+06  2816.796899  0.998716
# 2  Regularización Ridge  9.292430e+06  3048.348718  0.998496

# %%
# modelo
reg_lasso_1 = Lasso(alpha = 10.0, max_iter = 2083)

# entrenamiento
reg_lasso_1.fit(X_train_final, y_train)

# prediccion
y_pred = reg_lasso_1.predict(X_test_final)
y_pred

# metricas
mse_l4 = mean_squared_error(y_test, y_pred)
rmse_l4 = np.sqrt(mse_l4)
r2_l4 = r2_score(y_test, y_pred)

print("MSE: ", mse_l4)
print("RMSE: ", rmse_l4)
print("Coeficiente de determinación: ", r2_l4)
# Out:
# MSE:  6043484.23681644
# RMSE:  2458.3499012175707
# Coeficiente de determinación:  0.9990218393681194
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.091e+09, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# Después de varias pruebas, lo que optimiza el modelo son los hiperparámetros alpha=10.0 y max_iter = 2083

# %% [markdown]
# Optimizar alpha: Usa validación cruzada para encontrar el mejor valor de alpha

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'alpha': [0.1, 0.5, 1.0, 5.0, 10.0]}
grid = GridSearchCV(Lasso(max_iter=2000), param_grid, cv=5, scoring='neg_mean_squared_error')
grid.fit(X_train_final, y_train)
print("Mejor alpha:", grid.best_params_['alpha'])
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.842e+09, tolerance: 1.061e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.674e+09, tolerance: 7.818e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.899e+09, tolerance: 1.112e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.074e+09, tolerance: 1.203e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.068e+09, tolerance: 1.228e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.900e+09, tolerance: 1.061e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.706e+09, tolerance: 7.818e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.028e+09, tolerance: 1.112e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.151e+09, tolerance: 1.203e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.143e+09, tolerance: 1.228e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.952e+09, tolerance: 1.061e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.753e+09, tolerance: 7.818e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.187e+09, tolerance: 1.112e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.220e+09, tolerance: 1.203e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.179e+09, tolerance: 1.228e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.337e+09, tolerance: 1.061e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.036e+09, tolerance: 7.818e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.092e+09, tolerance: 1.112e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.535e+09, tolerance: 1.203e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.850e+09, tolerance: 1.228e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.180e+09, tolerance: 1.061e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.021e+09, tolerance: 7.818e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.648e+09, tolerance: 1.112e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.853e+09, tolerance: 1.203e+09
#   model = cd_fast.enet_coordinate_descent(
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.500e+09, tolerance: 1.228e+09
#   model = cd_fast.enet_coordinate_descent(
# Mejor alpha: 10.0
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.224e+09, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(

# %%
#guardado del modeelo

from joblib import dump

# Guardar el modelo en un archivo
dump(reg_lasso_1, "Regresion_regularizada_Lasso.sav")
print("Modelo guardado correctamente.")
# Out:
# Modelo guardado correctamente.
